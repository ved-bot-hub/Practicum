# %% [markdown]
# <a href="https://colab.research.google.com/github/ved-bot-hub/Practicum/blob/main/Practicum.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sqlite3

# Connect to a database (or create it if it doesn't exist)
conn = sqlite3.connect('mydatabase.db')
cursor = conn.cursor()

# %%
import pandas as pd

# Replace 'your_database.xlsx' with the actual path to your Excel file
excel_file_path = '/Users/vedant/Desktop/Practicum - BAX 462/RentIncreaseDataPracticum.xlsx'

# Load the data from the Excel file into a pandas DataFrame
try:
    df = pd.read_excel(excel_file_path)
    print("Data loaded successfully!")
    # Display the first few rows and information about the DataFrame
    display(df.head())
    display(df.info())
except FileNotFoundError:
    print(f"Error: The file '{excel_file_path}' was not found.")
except Exception as e:
    print(f"An error occurred: {e}")
